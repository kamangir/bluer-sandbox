# %% [markdown]
# # offline LLM

# %%
from bluer_sandbox import notebooks

from bluer_options import string
from bluer_objects import objects

from llama_cpp import Llama

from bluer_sandbox.host import signature
from bluer_sandbox.offline_llm.model.functions import get
from bluer_sandbox.logger import logger

logger.info(f"{'.'.join(signature())},\nbuilt on {string.pretty_date()}")
# Out:
# 🌀  bluer_sandbox-5.86.1.bluer_ai-12.134.1.bluer_objects-6.94.1.bluer_options-5.84.1.torch-2.2.2.Python 3.12.9.Darwin 23.6.0..Jupyter-Notebook,
# built on 20 April 2025, 20:03:14

# %% [markdown]
# ---

# %%
tiny = False

# %%
model_object_name = get("object_name", tiny=tiny)
model_filename = get("filename", tiny=tiny)

model_path = objects.path_of(
    object_name = model_object_name,
    filename = model_filename,
)

# %%
llm = Llama(
    model_path=model_path,
    backend='cpu',
)
# Out:
# llama_model_load_from_file_impl: using device Metal (Apple M3 Pro) - 12287 MiB free
# llama_model_loader: loaded meta data with 20 key-value pairs and 291 tensors from /Users/kamangir/storage/abcli/offline-llm-model-object/mistral-7b-instruct-v0.1.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = mistralai_mistral-7b-instruct-v0.1
# llama_model_loader: - kv   2:                       llama.context_length u32              = 32768
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   4:                          llama.block_count u32              = 32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 14336
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv   7:                 llama.attention.head_count u32              = 32
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32              = 8
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  10:                       llama.rope.freq_base f32              = 10000.000000
# llama_model_loader: - kv  11:                          general.file_type u32              = 15
# llama_model_loader: - kv  12:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  13:                      tokenizer.ggml.tokens arr[str,32000]   = ["<unk>", "<s>", "</s>", "<0x00>", "<...
# llama_model_loader: - kv  14:                      tokenizer.ggml.scores arr[f32,32000]   = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  15:                  tokenizer.ggml.token_type arr[i32,32000]   = [2, 3, 3, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# llama_model_loader: - kv  16:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  17:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  18:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  19:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:   65 tensors
# llama_model_loader: - type q4_K:  193 tensors
# llama_model_loader: - type q6_K:   33 tensors
# print_info: file format = GGUF V2
# print_info: file type   = Q4_K - Medium
# print_info: file size   = 4.07 GiB (4.83 BPW)
# init_tokenizer: initializing tokenizer for type 1
# load: control token:      2 '</s>' is not marked as EOG
# load: control token:      1 '<s>' is not marked as EOG
# load: special_eos_id is not in special_eog_ids - the tokenizer config may be incorrect
# load: special tokens cache size = 3
# load: token to piece cache size = 0.1637 MB
# print_info: arch             = llama
# print_info: vocab_only       = 0
# print_info: n_ctx_train      = 32768
# print_info: n_embd           = 4096
# print_info: n_layer          = 32
# print_info: n_head           = 32
# print_info: n_head_kv        = 8
# print_info: n_rot            = 128
# print_info: n_swa            = 0
# print_info: n_embd_head_k    = 128
# print_info: n_embd_head_v    = 128
# print_info: n_gqa            = 4
# print_info: n_embd_k_gqa     = 1024
# print_info: n_embd_v_gqa     = 1024
# print_info: f_norm_eps       = 0.0e+00
# print_info: f_norm_rms_eps   = 1.0e-05
# print_info: f_clamp_kqv      = 0.0e+00
# print_info: f_max_alibi_bias = 0.0e+00
# print_info: f_logit_scale    = 0.0e+00
# print_info: f_attn_scale     = 0.0e+00
# print_info: n_ff             = 14336
# print_info: n_expert         = 0
# print_info: n_expert_used    = 0
# print_info: causal attn      = 1
# print_info: pooling type     = 0
# print_info: rope type        = 0
# print_info: rope scaling     = linear
# print_info: freq_base_train  = 10000.0
# print_info: freq_scale_train = 1
# print_info: n_ctx_orig_yarn  = 32768
# print_info: rope_finetuned   = unknown
# print_info: ssm_d_conv       = 0
# print_info: ssm_d_inner      = 0
# print_info: ssm_d_state      = 0
# print_info: ssm_dt_rank      = 0
# print_info: ssm_dt_b_c_rms   = 0
# print_info: model type       = 7B
# print_info: model params     = 7.24 B
# print_info: general.name     = mistralai_mistral-7b-instruct-v0.1
# print_info: vocab type       = SPM
# print_info: n_vocab          = 32000
# print_info: n_merges         = 0
# print_info: BOS token        = 1 '<s>'
# print_info: EOS token        = 2 '</s>'
# print_info: UNK token        = 0 '<unk>'
# print_info: LF token         = 13 '<0x0A>'
# print_info: EOG token        = 2 '</s>'
# print_info: max token length = 48
# load_tensors: loading model tensors, this can take a while... (mmap = true)
# load_tensors: layer   0 assigned to device CPU
# load_tensors: layer   1 assigned to device CPU
# load_tensors: layer   2 assigned to device CPU
# load_tensors: layer   3 assigned to device CPU
# load_tensors: layer   4 assigned to device CPU
# load_tensors: layer   5 assigned to device CPU
# load_tensors: layer   6 assigned to device CPU
# load_tensors: layer   7 assigned to device CPU
# load_tensors: layer   8 assigned to device CPU
# load_tensors: layer   9 assigned to device CPU
# load_tensors: layer  10 assigned to device CPU
# load_tensors: layer  11 assigned to device CPU
# load_tensors: layer  12 assigned to device CPU
# load_tensors: layer  13 assigned to device CPU
# load_tensors: layer  14 assigned to device CPU
# load_tensors: layer  15 assigned to device CPU
# load_tensors: layer  16 assigned to device CPU
# load_tensors: layer  17 assigned to device CPU
# load_tensors: layer  18 assigned to device CPU
# load_tensors: layer  19 assigned to device CPU
# load_tensors: layer  20 assigned to device CPU
# load_tensors: layer  21 assigned to device CPU
# load_tensors: layer  22 assigned to device CPU
# load_tensors: layer  23 assigned to device CPU
# load_tensors: layer  24 assigned to device CPU
# load_tensors: layer  25 assigned to device CPU
# load_tensors: layer  26 assigned to device CPU
# load_tensors: layer  27 assigned to device CPU
# load_tensors: layer  28 assigned to device CPU
# load_tensors: layer  29 assigned to device CPU
# load_tensors: layer  30 assigned to device CPU
# load_tensors: layer  31 assigned to device CPU
# load_tensors: layer  32 assigned to device CPU
# load_tensors: tensor 'token_embd.weight' (q4_K) (and 290 others) cannot be used with preferred buffer type CPU_AARCH64, using CPU instead
# load_tensors: offloading 0 repeating layers to GPU
# load_tensors: offloaded 0/33 layers to GPU
# load_tensors:   CPU_Mapped model buffer size =  4165.37 MiB
# .................................................................................................
# llama_init_from_model: n_seq_max     = 1
# llama_init_from_model: n_ctx         = 512
# llama_init_from_model: n_ctx_per_seq = 512
# llama_init_from_model: n_batch       = 512
# llama_init_from_model: n_ubatch      = 512
# llama_init_from_model: flash_attn    = 0
# llama_init_from_model: freq_base     = 10000.0
# llama_init_from_model: freq_scale    = 1
# llama_init_from_model: n_ctx_per_seq (512) < n_ctx_train (32768) -- the full capacity of the model will not be utilized
# ggml_metal_init: allocating
# ggml_metal_init: found device: Apple M3 Pro
# ggml_metal_init: picking default device: Apple M3 Pro
# ggml_metal_load_library: using embedded metal library
# ggml_metal_load_library: error: Error Domain=MTLLibraryErrorDomain Code=3 "program_source:2999:9: error: invalid type 'const constant ggml_metal_kargs_bin &' for buffer declaration
#         constant ggml_metal_kargs_bin & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:1901:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb00;
#     ^
# program_source:1902:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb01;
#     ^
# program_source:1903:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb02;
#     ^
# program_source:1904:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb03;
#     ^
# program_source:1909:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb10;
#     ^
# program_source:1910:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb11;
#     ^
# program_source:1911:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb12;
#     ^
# program_source:1912:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb13;
#     ^
# program_source:1917:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb0;
#     ^
# program_source:1918:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb1;
#     ^
# program_source:1919:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb2;
#     ^
# program_source:1920:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb3;
#     ^
# program_source:1921:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t offs;
#     ^
# program_source:2999:18: note: type 'ggml_metal_kargs_bin' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_bin & args,
#                  ^
# program_source:3025:9: error: invalid type 'const constant ggml_metal_kargs_bin &' for buffer declaration
#         constant ggml_metal_kargs_bin & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:1901:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb00;
#     ^
# program_source:1902:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb01;
#     ^
# program_source:1903:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb02;
#     ^
# program_source:1904:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb03;
#     ^
# program_source:1909:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb10;
#     ^
# program_source:1910:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb11;
#     ^
# program_source:1911:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb12;
#     ^
# program_source:1912:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb13;
#     ^
# program_source:1917:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb0;
#     ^
# program_source:1918:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb1;
#     ^
# program_source:1919:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb2;
#     ^
# program_source:1920:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb3;
#     ^
# program_source:1921:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t offs;
#     ^
# program_source:3025:18: note: type 'ggml_metal_kargs_bin' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_bin & args,
#                  ^
# program_source:3051:9: error: invalid type 'const constant ggml_metal_kargs_bin &' for buffer declaration
#         constant ggml_metal_kargs_bin & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:1901:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb00;
#     ^
# program_source:1902:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb01;
#     ^
# program_source:1903:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb02;
#     ^
# program_source:1904:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb03;
#     ^
# program_source:1909:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb10;
#     ^
# program_source:1910:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb11;
#     ^
# program_source:1911:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb12;
#     ^
# program_source:1912:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb13;
#     ^
# program_source:1917:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb0;
#     ^
# program_source:1918:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb1;
#     ^
# program_source:1919:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb2;
#     ^
# program_source:1920:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb3;
#     ^
# program_source:1921:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t offs;
#     ^
# program_source:3051:18: note: type 'ggml_metal_kargs_bin' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_bin & args,
#                  ^
# program_source:3077:9: error: invalid type 'const constant ggml_metal_kargs_bin &' for buffer declaration
#         constant ggml_metal_kargs_bin & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:1901:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb00;
#     ^
# program_source:1902:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb01;
#     ^
# program_source:1903:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb02;
#     ^
# program_source:1904:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb03;
#     ^
# program_source:1909:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb10;
#     ^
# program_source:1910:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb11;
#     ^
# program_source:1911:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb12;
#     ^
# program_source:1912:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb13;
#     ^
# program_source:1917:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb0;
#     ^
# program_source:1918:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb1;
#     ^
# program_source:1919:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb2;
#     ^
# program_source:1920:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb3;
#     ^
# program_source:1921:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t offs;
#     ^
# program_source:3077:18: note: type 'ggml_metal_kargs_bin' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_bin & args,
#                  ^
# program_source:3104:9: error: invalid type 'const constant ggml_metal_kargs_repeat &' for buffer declaration
#         constant ggml_metal_kargs_repeat & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:1929:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb00;
#     ^
# program_source:1930:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb01;
#     ^
# program_source:1931:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb02;
#     ^
# program_source:1932:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb03;
#     ^
# program_source:1937:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb0;
#     ^
# program_source:1938:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb1;
#     ^
# program_source:1939:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb2;
#     ^
# program_source:1940:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb3;
#     ^
# program_source:3104:18: note: type 'ggml_metal_kargs_repeat' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_repeat & args,
#                  ^
# program_source:3129:12: error: 'host_name' attribute requires Metal language standard macos-metal2.2 or higher
# template [[host_name("kernel_repeat_f32")]] kernel kernel_repeat_t kernel_repeat<float>;
#            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:3130:12: error: 'host_name' attribute requires Metal language standard macos-metal2.2 or higher
# template [[host_name("kernel_repeat_f16")]] kernel kernel_repeat_t kernel_repeat<half>;
#            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:3131:12: error: 'host_name' attribute requires Metal language standard macos-metal2.2 or higher
# template [[host_name("kernel_repeat_i32")]] kernel kernel_repeat_t kernel_repeat<int>;
#            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:3132:12: error: 'host_name' attribute requires Metal language standard macos-metal2.2 or higher
# template [[host_name("kernel_repeat_i16")]] kernel kernel_repeat_t kernel_repeat<short>;
#            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:3137:9: error: invalid type 'const constant ggml_metal_kargs_bin &' for buffer declaration
#         constant ggml_metal_kargs_bin & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:1901:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb00;
#     ^
# program_source:1902:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb01;
#     ^
# program_source:1903:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb02;
#     ^
# program_source:1904:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb03;
#     ^
# program_source:1909:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb10;
#     ^
# program_source:1910:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb11;
#     ^
# program_source:1911:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb12;
#     ^
# program_source:1912:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb13;
#     ^
# program_source:1917:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb0;
#     ^
# program_source:1918:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb1;
#     ^
# program_source:1919:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb2;
#     ^
# program_source:1920:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb3;
#     ^
# program_source:1921:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t offs;
#     ^
# program_source:3137:18: note: type 'ggml_metal_kargs_bin' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_bin & args,
#                  ^
# program_source:3147:9: error: invalid type 'const constant ggml_metal_kargs_bin &' for buffer declaration
#         constant ggml_metal_kargs_bin & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:1901:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb00;
#     ^
# program_source:1902:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb01;
#     ^
# program_source:1903:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb02;
#     ^
# program_source:1904:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb03;
#     ^
# program_source:1909:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb10;
#     ^
# program_source:1910:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb11;
#     ^
# program_source:1911:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb12;
#     ^
# program_source:1912:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb13;
#     ^
# program_source:1917:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb0;
#     ^
# program_source:1918:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb1;
#     ^
# program_source:1919:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb2;
#     ^
# program_source:1920:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb3;
#     ^
# program_source:1921:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t offs;
#     ^
# program_source:3147:18: note: type 'ggml_metal_kargs_bin' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_bin & args,
#                  ^
# program_source:3157:9: error: invalid type 'const constant ggml_metal_kargs_bin &' for buffer declaration
#         constant ggml_metal_kargs_bin & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:1901:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb00;
#     ^
# program_source:1902:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb01;
#     ^
# program_source:1903:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb02;
#     ^
# program_source:1904:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb03;
#     ^
# program_source:1909:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb10;
#     ^
# program_source:1910:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb11;
#     ^
# program_source:1911:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb12;
#     ^
# program_source:1912:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb13;
#     ^
# program_source:1917:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb0;
#     ^
# program_source:1918:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb1;
#     ^
# program_source:1919:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb2;
#     ^
# program_source:1920:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb3;
#     ^
# program_source:1921:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t offs;
#     ^
# program_source:3157:18: note: type 'ggml_metal_kargs_bin' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_bin & args,
#                  ^
# program_source:3167:9: error: invalid type 'const constant ggml_metal_kargs_bin &' for buffer declaration
#         constant ggml_metal_kargs_bin & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:1901:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb00;
#     ^
# program_source:1902:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb01;
#     ^
# program_source:1903:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb02;
#     ^
# program_source:1904:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb03;
#     ^
# program_source:1909:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb10;
#     ^
# program_source:1910:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb11;
#     ^
# program_source:1911:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb12;
#     ^
# program_source:1912:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb13;
#     ^
# program_source:1917:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb0;
#     ^
# program_source:1918:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb1;
#     ^
# program_source:1919:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb2;
#     ^
# program_source:1920:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb3;
#     ^
# program_source:1921:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t offs;
#     ^
# program_source:3167:18: note: type 'ggml_metal_kargs_bin' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_bin & args,
#                  ^
# program_source:3322:9: error: invalid type 'const constant ggml_metal_kargs_sum_rows &' for buffer declaration
#         constant ggml_metal_kargs_sum_rows & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:2184:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne00;
#     ^
# program_source:2185:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne01;
#     ^
# program_source:2186:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne02;
#     ^
# program_source:2187:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne03;
#     ^
# program_source:2188:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb00;
#     ^
# program_source:2189:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb01;
#     ^
# program_source:2190:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb02;
#     ^
# program_source:2191:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb03;
#     ^
# program_source:2192:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne10;
#     ^
# program_source:2193:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne11;
#     ^
# program_source:2194:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne12;
#     ^
# program_source:2195:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne13;
#     ^
# program_source:2196:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb10;
#     ^
# program_source:2197:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb11;
#     ^
# program_source:2198:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb12;
#     ^
# program_source:2199:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb13;
#     ^
# program_source:2200:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne0;
#     ^
# program_source:2201:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne1;
#     ^
# program_source:2202:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne2;
#     ^
# program_source:2203:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne3;
#     ^
# program_source:2204:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb0;
#     ^
# program_source:2205:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb1;
#     ^
# program_source:2206:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb2;
#     ^
# program_source:2207:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb3;
#     ^
# program_source:3322:18: note: type 'ggml_metal_kargs_sum_rows' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_sum_rows & args,
#                  ^
# program_source:3349:9: error: invalid type 'const constant ggml_metal_kargs_soft_max &' for buffer declaration
#         constant ggml_metal_kargs_soft_max & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:2211:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne00;
#     ^
# program_source:2212:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne01;
#     ^
# program_source:2213:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne02;
#     ^
# program_source:3349:18: note: type 'ggml_metal_kargs_soft_max' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_soft_max & args,
#                  ^
# program_source:3445:9: error: invalid type 'const constant ggml_metal_kargs_soft_max &' for buffer declaration
#         constant ggml_metal_kargs_soft_max & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:2211:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne00;
#     ^
# program_source:2212:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne01;
#     ^
# program_source:2213:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne02;
#     ^
# program_source:3445:18: note: type 'ggml_metal_kargs_soft_max' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_soft_max & args,
#                  ^
# program_source:3541:12: error: 'host_name' attribute requires Metal language standard macos-metal2.2 or higher
# template [[host_name("kernel_soft_max_f16")]]   kernel kernel_soft_max_t   kernel_soft_max<half>;
#            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:3542:12: error: 'host_name' attribute requires Metal language standard macos-metal2.2 or higher
# template [[host_name("kernel_soft_max_f32")]]   kernel kernel_soft_max_t   kernel_soft_max<float>;
#            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:3543:12: error: 'host_name' attribute requires Metal language standard macos-metal2.2 or higher
# template [[host_name("kernel_soft_max_f16_4")]] kernel kernel_soft_max_4_t kernel_soft_max_4<half4>;
#            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:3544:12: error: 'host_name' attribute requires Metal language standard macos-metal2.2 or higher
# template [[host_name("kernel_soft_max_f32_4")]] kernel kernel_soft_max_4_t kernel_soft_max_4<float4>;
#            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:3549:9: error: invalid type 'const constant ggml_metal_kargs_diag_mask_inf &' for buffer declaration
#         constant ggml_metal_kargs_diag_mask_inf & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:2222:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne00;
#     ^
# program_source:2223:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne01;
#     ^
# program_source:3549:18: note: type 'ggml_metal_kargs_diag_mask_inf' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_diag_mask_inf & args,
#                  ^
# program_source:3565:9: error: invalid type 'const constant ggml_metal_kargs_diag_mask_inf &' for buffer declaration
#         constant ggml_metal_kargs_diag_mask_inf & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:2222:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne00;
#     ^
# program_source:2223:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne01;
#     ^
# program_source:3565:18: note: type 'ggml_metal_kargs_diag_mask_inf' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_diag_mask_inf & args,
#                  ^
# program_source:3592:9: error: invalid type 'const constant ggml_metal_kargs_ssm_conv &' for buffer declaration
#         constant ggml_metal_kargs_ssm_conv & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:2228:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne00;
#     ^
# program_source:2229:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne01;
#     ^
# program_source:2230:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne02;
#     ^
# program_source:2231:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb00;
#     ^
# program_source:2232:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb01;
#     ^
# program_source:2233:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb02;
#     ^
# program_source:2234:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne10;
#     ^
# program_source:2235:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne11;
#     ^
# program_source:2236:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb10;
#     ^
# program_source:2237:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb11;
#     ^
# program_source:2238:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne0;
#     ^
# program_source:2239:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne1;
#     ^
# program_source:2240:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne2;
#     ^
# program_source:2241:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb0;
#     ^
# program_source:2242:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb1;
#     ^
# program_source:2243:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb2;
#     ^
# program_source:3592:18: note: type 'ggml_metal_kargs_ssm_conv' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_ssm_conv & args,
#                  ^
# program_source:3628:9: error: invalid type 'const constant ggml_metal_kargs_ssm_scan &' for buffer declaration
#         constant ggml_metal_kargs_ssm_scan & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:2247:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  d_state;
#     ^
# program_source:2248:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  d_inner;
#     ^
# program_source:2249:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  n_seq_tokens;
#     ^
# program_source:2250:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  n_seqs;
#     ^
# program_source:2251:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb00;
#     ^
# program_source:2252:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb01;
#     ^
# program_source:2253:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb02;
#     ^
# program_source:2254:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb10;
#     ^
# program_source:2255:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb11;
#     ^
# program_source:2256:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb12;
#     ^
# program_source:2257:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb13;
#     ^
# program_source:2258:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb20;
#     ^
# program_source:2259:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb21;
#     ^
# program_source:2260:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb22;
#     ^
# program_source:2261:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb30;
#     ^
# program_source:2262:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb31;
#     ^
# program_source:2263:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb40;
#     ^
# program_source:2264:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb41;
#     ^
# program_source:2265:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb42;
#     ^
# program_source:2266:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb50;
#     ^
# program_source:2267:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb51;
#     ^
# program_source:2268:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb52;
#     ^
# program_source:3628:18: note: type 'ggml_metal_kargs_ssm_scan' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_ssm_scan & args,
#                  ^
# program_source:3673:9: error: invalid type 'const constant int64_t &' (aka 'const constant long &') for buffer declaration
#         constant    int64_t & ncols,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:3673:21: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#         constant    int64_t & ncols,
#                     ^
# program_source:3674:9: error: invalid type 'const constant uint64_t &' (aka 'const constant unsigned long &') for buffer declaration
#         constant   uint64_t & nb01,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:3674:20: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#         constant   uint64_t & nb01,
#                    ^
# program_source:3728:9: error: invalid type 'const constant ggml_metal_kargs_norm &' for buffer declaration
#         constant ggml_metal_kargs_norm & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:2134:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb01;
#     ^
# program_source:3728:18: note: type 'ggml_metal_kargs_norm' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_norm & args,
#                  ^
# program_source:3795:9: error: invalid type 'const constant ggml_metal_kargs_rms_norm &' for buffer declaration
#         constant ggml_metal_kargs_rms_norm & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:2141:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb01;
#     ^
# program_source:3795:18: note: type 'ggml_metal_kargs_rms_norm' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_rms_norm & args,
#                  ^
# program_source:3841:9: error: invalid type 'const constant ggml_metal_kargs_group_norm &' for buffer declaration
#         constant ggml_metal_kargs_group_norm & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:2146:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne00;
#     ^
# program_source:2147:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne01;
#     ^
# program_source:2148:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  ne02;
#     ^
# program_source:2149:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb00;
#     ^
# program_source:2150:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb01;
#     ^
# program_source:2151:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb02;
#     ^
# program_source:3841:18: note: type 'ggml_metal_kargs_group_norm' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_group_norm & args,
#                  ^
# program_source:4092:9: error: invalid type 'const constant ggml_metal_kargs_mul_mv &' for buffer declaration
#         constant ggml_metal_kargs_mul_mv & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:2050:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb00;
#     ^
# program_source:2051:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb01;
#     ^
# program_source:2052:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb02;
#     ^
# program_source:2053:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb03;
#     ^
# program_source:2057:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb10;
#     ^
# program_source:2058:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb11;
#     ^
# program_source:2059:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb12;
#     ^
# program_source:2060:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb13;
#     ^
# program_source:4092:18: note: type 'ggml_metal_kargs_mul_mv' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_mul_mv & args,
#                  ^
# program_source:4103:9: error: invalid type 'const constant ggml_metal_kargs_mul_mv &' for buffer declaration
#         constant ggml_metal_kargs_mul_mv & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:2050:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb00;
#     ^
# program_source:2051:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb01;
#     ^
# program_source:2052:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb02;
#     ^
# program_source:2053:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb03;
#     ^
# program_source:2057:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb10;
#     ^
# program_source:2058:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb11;
#     ^
# program_source:2059:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb12;
#     ^
# program_source:2060:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb13;
#     ^
# program_source:4103:18: note: type 'ggml_metal_kargs_mul_mv' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_mul_mv & args,
#                  ^
# program_source:4114:9: error: invalid type 'const constant ggml_metal_kargs_mul_mv &' for buffer declaration
#         constant ggml_metal_kargs_mul_mv & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:2050:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb00;
#     ^
# program_source:2051:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb01;
#     ^
# program_source:2052:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb02;
#     ^
# program_source:2053:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb03;
#     ^
# program_source:2057:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb10;
#     ^
# program_source:2058:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb11;
#     ^
# program_source:2059:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb12;
#     ^
# program_source:2060:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb13;
#     ^
# program_source:4114:18: note: type 'ggml_metal_kargs_mul_mv' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_mul_mv & args,
#                  ^
# program_source:4125:9: error: invalid type 'const constant ggml_metal_kargs_mul_mv &' for buffer declaration
#         constant ggml_metal_kargs_mul_mv & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:2050:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb00;
#     ^
# program_source:2051:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb01;
#     ^
# program_source:2052:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb02;
#     ^
# program_source:2053:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb03;
#     ^
# program_source:2057:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb10;
#     ^
# program_source:2058:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb11;
#     ^
# program_source:2059:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb12;
#     ^
# program_source:2060:5: note: type 'uint64_t' (aka 'unsigned long') cannot be used in buffer pointee type
#     uint64_t nb13;
#     ^
# program_source:4125:18: note: type 'ggml_metal_kargs_mul_mv' cannot be used in buffer pointee type
#         constant ggml_metal_kargs_mul_mv & args,
#                  ^
# program_source:4212:3: error: 'host_name' attribute requires Metal language standard macos-metal2.2 or higher
# [[host_name("kernel_mul_mv_q8_0_f32")]]
#   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:4214:9: error: invalid type 'const constant ggml_metal_kargs_mul_mv &' for buffer declaration
#         constant ggml_metal_kargs_mul_mv & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ...
#            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:8830:12: error: 'host_name' attribute requires Metal language standard macos-metal2.2 or higher
# template [[host_name("kernel_mul_mv_id_iq2_s_f32")]]   kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<kernel_mul_mv_iq2_s_f32_impl>>;
#            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:8831:12: error: 'host_name' attribute requires Metal language standard macos-metal2.2 or higher
# template [[host_name("kernel_mul_mv_id_iq4_nl_f32")]]  kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<kernel_mul_mv_iq4_nl_f32_impl>>;
#            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:8832:12: error: 'host_name' attribute requires Metal language standard macos-metal2.2 or higher
# template [[host_name("kernel_mul_mv_id_iq4_xs_f32")]]  kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<kernel_mul_mv_iq4_xs_f32_impl>>;
#            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:8837:9: error: invalid type 'const constant ggml_metal_kargs_pool_2d &' for buffer declaration
#         constant    ggml_metal_kargs_pool_2d & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:2373:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  IH;
#     ^
# program_source:2374:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  IW;
#     ^
# program_source:2375:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  OH;
#     ^
# program_source:2376:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  OW;
#     ^
# program_source:2377:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  parallel_elements;
#     ^
# program_source:8837:21: note: type 'ggml_metal_kargs_pool_2d' cannot be used in buffer pointee type
#         constant    ggml_metal_kargs_pool_2d & args,
#                     ^
# program_source:8875:9: error: invalid type 'const constant ggml_metal_kargs_pool_2d &' for buffer declaration
#         constant    ggml_metal_kargs_pool_2d & args,
#         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# program_source:2373:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  IH;
#     ^
# program_source:2374:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  IW;
#     ^
# program_source:2375:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  OH;
#     ^
# program_source:2376:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  OW;
#     ^
# program_source:2377:5: note: type 'int64_t' (aka 'long') cannot be used in buffer pointee type
#     int64_t  parallel_elements;
#     ^
# program_source:8875:21: note: type 'ggml_metal_kargs_pool_2d' cannot be used in buffer pointee type
#         constant    ggml_metal_kargs_pool_2d & args,
#                     ^
# program_source:8725:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, tgpig, tiisg);
#     ^
# program_source:8807:35: note: in instantiation of function template specialization 'mmv_fn<&kernel_mul_mv_impl>' requested here
# typedef decltype(kernel_mul_mv_id<mmv_fn<kernel_mul_mv_impl<float, float4, float, float4>>>) kernel_mul_mv_id_t;
#                                   ^
# program_source:8725:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, tgpig, tiisg);
#     ^
# program_source:8810:99: note: in instantiation of function template specialization 'mmv_fn<&kernel_mul_mv_impl>' requested here
# template [[host_name("kernel_mul_mv_id_f16_f32")]]     kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<kernel_mul_mv_impl<half, half4, float, float4>>>;
#                                                                                                   ^
# program_source:8739:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, shmem, tgpig, tiisg, sgitg);
#     ^
# program_source:8814:99: note: in instantiation of function template specialization 'mmv_fn<&kernel_mul_mv_q8_0_f32_impl>' requested here
# template [[host_name("kernel_mul_mv_id_q8_0_f32")]]    kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<kernel_mul_mv_q8_0_f32_impl>>;
#                                                                                                   ^
# program_source:8739:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, shmem, tgpig, tiisg, sgitg);
#     ^
# program_source:8815:99: note: in instantiation of function template specialization 'mmv_fn<&mul_vec_q_n_f32_impl>' requested here
# template [[host_name("kernel_mul_mv_id_q4_0_f32")]]    kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<mul_vec_q_n_f32_impl<block_q4_0, N_DST, N_SIMDGROUP, N_SIMDWIDTH>>>;
#                                                                                                   ^
# program_source:8739:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, shmem, tgpig, tiisg, sgitg);
#     ^
# program_source:8816:99: note: in instantiation of function template specialization 'mmv_fn<&mul_vec_q_n_f32_impl>' requested here
# template [[host_name("kernel_mul_mv_id_q4_1_f32")]]    kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<mul_vec_q_n_f32_impl<block_q4_1, N_DST, N_SIMDGROUP, N_SIMDWIDTH>>>;
#                                                                                                   ^
# program_source:8739:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, shmem, tgpig, tiisg, sgitg);
#     ^
# program_source:8817:99: note: in instantiation of function template specialization 'mmv_fn<&mul_vec_q_n_f32_impl>' requested here
# template [[host_name("kernel_mul_mv_id_q5_0_f32")]]    kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<mul_vec_q_n_f32_impl<block_q5_0, N_DST, N_SIMDGROUP, N_SIMDWIDTH>>>;
#                                                                                                   ^
# program_source:8739:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, shmem, tgpig, tiisg, sgitg);
#     ^
# program_source:8818:99: note: in instantiation of function template specialization 'mmv_fn<&mul_vec_q_n_f32_impl>' requested here
# template [[host_name("kernel_mul_mv_id_q5_1_f32")]]    kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<mul_vec_q_n_f32_impl<block_q5_1, N_DST, N_SIMDGROUP, N_SIMDWIDTH>>>;
#                                                                                                   ^
# program_source:8739:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, shmem, tgpig, tiisg, sgitg);
#     ^
# program_source:8819:99: note: in instantiation of function template specialization 'mmv_fn<&kernel_mul_mv_q2_K_f32_impl>' requested here
# template [[host_name("kernel_mul_mv_id_q2_K_f32")]]    kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<kernel_mul_mv_q2_K_f32_impl>>;
#                                                                                                   ^
# program_source:8739:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, shmem, tgpig, tiisg, sgitg);
#     ^
# program_source:8820:99: note: in instantiation of function template specialization 'mmv_fn<&kernel_mul_mv_q3_K_f32_impl>' requested here
# template [[host_name("kernel_mul_mv_id_q3_K_f32")]]    kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<kernel_mul_mv_q3_K_f32_impl>>;
#                                                                                                   ^
# program_source:8739:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, shmem, tgpig, tiisg, sgitg);
#     ^
# program_source:8821:99: note: in instantiation of function template specialization 'mmv_fn<&kernel_mul_mv_q4_K_f32_impl>' requested here
# template [[host_name("kernel_mul_mv_id_q4_K_f32")]]    kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<kernel_mul_mv_q4_K_f32_impl>>;
#                                                                                                   ^
# program_source:8739:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, shmem, tgpig, tiisg, sgitg);
#     ^
# program_source:8822:99: note: in instantiation of function template specialization 'mmv_fn<&kernel_mul_mv_q5_K_f32_impl>' requested here
# template [[host_name("kernel_mul_mv_id_q5_K_f32")]]    kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<kernel_mul_mv_q5_K_f32_impl>>;
#                                                                                                   ^
# program_source:8739:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, shmem, tgpig, tiisg, sgitg);
#     ^
# program_source:8823:99: note: in instantiation of function template specialization 'mmv_fn<&kernel_mul_mv_q6_K_f32_impl>' requested here
# template [[host_name("kernel_mul_mv_id_q6_K_f32")]]    kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<kernel_mul_mv_q6_K_f32_impl>>;
#                                                                                                   ^
# program_source:8739:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, shmem, tgpig, tiisg, sgitg);
#     ^
# program_source:8824:99: note: in instantiation of function template specialization 'mmv_fn<&kernel_mul_mv_iq1_s_f32_impl>' requested here
# template [[host_name("kernel_mul_mv_id_iq1_s_f32")]]   kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<kernel_mul_mv_iq1_s_f32_impl>>;
#                                                                                                   ^
# program_source:8739:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, shmem, tgpig, tiisg, sgitg);
#     ^
# program_source:8825:99: note: in instantiation of function template specialization 'mmv_fn<&kernel_mul_mv_iq1_m_f32_impl>' requested here
# template [[host_name("kernel_mul_mv_id_iq1_m_f32")]]   kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<kernel_mul_mv_iq1_m_f32_impl>>;
#                                                                                                   ^
# program_source:8739:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, shmem, tgpig, tiisg, sgitg);
#     ^
# program_source:8826:99: note: in instantiation of function template specialization 'mmv_fn<&kernel_mul_mv_iq2_xxs_f32_impl>' requested here
# template [[host_name("kernel_mul_mv_id_iq2_xxs_f32")]] kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<kernel_mul_mv_iq2_xxs_f32_impl>>;
#                                                                                                   ^
# program_source:8739:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, shmem, tgpig, tiisg, sgitg);
#     ^
# program_source:8827:99: note: in instantiation of function template specialization 'mmv_fn<&kernel_mul_mv_iq2_xs_f32_impl>' requested here
# template [[host_name("kernel_mul_mv_id_iq2_xs_f32")]]  kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<kernel_mul_mv_iq2_xs_f32_impl>>;
#                                                                                                   ^
# program_source:8739:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, shmem, tgpig, tiisg, sgitg);
#     ^
# program_source:8828:99: note: in instantiation of function template specialization 'mmv_fn<&kernel_mul_mv_iq3_xxs_f32_impl>' requested here
# template [[host_name("kernel_mul_mv_id_iq3_xxs_f32")]] kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<kernel_mul_mv_iq3_xxs_f32_impl>>;
#                                                                                                   ^
# program_source:8739:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, shmem, tgpig, tiisg, sgitg);
#     ^
# program_source:8829:99: note: in instantiation of function template specialization 'mmv_fn<&kernel_mul_mv_iq3_s_f32_impl>' requested here
# template [[host_name("kernel_mul_mv_id_iq3_s_f32")]]   kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<kernel_mul_mv_iq3_s_f32_impl>>;
#                                                                                                   ^
# program_source:8739:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, shmem, tgpig, tiisg, sgitg);
#     ^
# program_source:8830:99: note: in instantiation of function template specialization 'mmv_fn<&kernel_mul_mv_iq2_s_f32_impl>' requested here
# template [[host_name("kernel_mul_mv_id_iq2_s_f32")]]   kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<kernel_mul_mv_iq2_s_f32_impl>>;
#                                                                                                   ^
# program_source:8739:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, shmem, tgpig, tiisg, sgitg);
#     ^
# program_source:8831:99: note: in instantiation of function template specialization 'mmv_fn<&kernel_mul_mv_iq4_nl_f32_impl>' requested here
# template [[host_name("kernel_mul_mv_id_iq4_nl_f32")]]  kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<kernel_mul_mv_iq4_nl_f32_impl>>;
#                                                                                                   ^
# program_source:8739:5: error: taking address of function is not allowed
#     impl_fn(args, src0, src1, dst, shmem, tgpig, tiisg, sgitg);
#     ^
# program_source:8832:99: note: in instantiation of function template specialization 'mmv_fn<&kernel_mul_mv_iq4_xs_f32_impl>' requested here
# template [[host_name("kernel_mul_mv_id_iq4_xs_f32")]]  kernel kernel_mul_mv_id_t kernel_mul_mv_id<mmv_fn<kernel_mul_mv_iq4_xs_f32_impl>>;
#                                                                                                   ^
# }
# ggml_metal_init: error: metal library is nil
# ggml_backend_metal_device_init: error: failed to allocate context
# llama_init_from_model: failed to initialize Metal backend
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 llm = Llama(
#       2     model_path=model_path,
#       3     backend='cpu',
#       4 )
#
# File ~/miniconda3/lib/python3.12/site-packages/llama_cpp/llama.py:393, in Llama.__init__(self, model_path, n_gpu_layers, split_mode, main_gpu, tensor_split, rpc_servers, vocab_only, use_mmap, use_mlock, kv_overrides, seed, n_ctx, n_batch, n_ubatch, n_threads, n_threads_batch, rope_scaling_type, pooling_type, rope_freq_base, rope_freq_scale, yarn_ext_factor, yarn_attn_factor, yarn_beta_fast, yarn_beta_slow, yarn_orig_ctx, logits_all, embedding, offload_kqv, flash_attn, no_perf, last_n_tokens_size, lora_base, lora_scale, lora_path, numa, chat_format, chat_handler, draft_model, tokenizer, type_k, type_v, spm_infill, verbose, **kwargs)
#     388     self.context_params.n_batch = self.n_batch
#     389     self.context_params.n_ubatch = min(self.n_batch, n_ubatch)
#     391 self._ctx = self._stack.enter_context(
#     392     contextlib.closing(
# --> 393         internals.LlamaContext(
#     394             model=self._model,
#     395             params=self.context_params,
#     396             verbose=self.verbose,
#     397         )
#     398     )
#     399 )
#     401 self._batch = self._stack.enter_context(
#     402     contextlib.closing(
#     403         internals.LlamaBatch(
#    (...)    409     )
#     410 )
#     412 self._lora_adapter: Optional[llama_cpp.llama_adapter_lora_p] = None
#
# File ~/miniconda3/lib/python3.12/site-packages/llama_cpp/_internals.py:255, in LlamaContext.__init__(self, model, params, verbose)
#     252 ctx = llama_cpp.llama_new_context_with_model(self.model.model, self.params)
#     254 if ctx is None:
# --> 255     raise ValueError("Failed to create llama_context")
#     257 self.ctx = ctx
#     259 def free_ctx():
#
# ValueError: Failed to create llama_context

# %%
del llm

# %% [markdown]
# ---

# %%
# END
